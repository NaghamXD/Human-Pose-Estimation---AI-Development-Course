# %%
import json
import yaml
import sys
import os
from   scipy.io   import  loadmat
import numpy as np
import pandas as pd
import logging.config
import re
import shutil
from pathlib import Path
from typing import Any
import random
import importlib
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor
from PIL import Image


# model
from sklearn.model_selection import train_test_split

# Deep Learning
import torch
# import torch.nn            as nn
# import torch.nn.functional as F
# from torch.optim.optimizer import Optimizer
# from torch.optim.lr_scheduler import LRScheduler
# from torch.utils.data import DataLoader
# from torch.utils.tensorboard import SummaryWriter
# import torchinfo
# from torchmetrics.classification import MulticlassAccuracy
# import torchvision
# from torchvision.transforms import v2 as TorchVisionTrns

sys.path.insert(0, '..')

from src.conf import settings
from src.common import cli
from utils import KeypointDataset, DetectDataset

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
# Out:
# BASE_DIR is set to: /Users/rashajaber/VScodeProjects/Human-Pose-Estimation---AI-Development-Course

# %% [markdown]
# ### Data Exploration

# %%
# Extract joints names from readme file:
def extract_joint_names(readme_path):
    with open(readme_path, 'r') as file:
        readme_content = file.read()
    # Use regular expression to find the section with body parts
    match = re.search(r"The ordering of joints is as follows:(.*?)If you use this dataset", readme_content, re.DOTALL)
    if match:
        labels_section = match.group(1).strip()
        joint_names = [line.strip() for line in labels_section.splitlines()]
    else:
        raise Exception(f"No labels found in the given path: {readme_path}")
    return joint_names

readme_path = settings.DATA_DIR.joinpath('README.txt')
joint_names = extract_joint_names(readme_path)
print(f"LSP Data Contains {len(joint_names)} joints which are: {joint_names}")

# Load .mat file of the joints[KeyPoints]:
def load_joint_annotations(mat_path):
    try:
        mat = loadmat(mat_path)
    except Exception as e:
        print(f"Error loading .mat file: {e}")
        raise
    key = [k for k in mat.keys() if k[0] != '_'][0] #joints
    joint_annotations = mat[key]
    return joint_annotations

mat_path = settings.LABELS_PATH
joint_annotations = load_joint_annotations(mat_path)
print(f"LSP Data Shape is : {joint_annotations.shape}")

# Get Images filenames:
def get_image_filenames(img_dir):
    return sorted([f for f in os.listdir(img_dir) if f.endswith('.png')])

def get_image_sizes(img_dir, image_filenames):
    sizes = []
    for filename in image_filenames:
        try:
            with Image.open(os.path.join(img_dir, filename)) as img:
                width, height = img.size
                sizes.append((width, height))
        except IOError:
            print(f"Error: Could not open or process file {filename}")

    return sizes
img_dir = settings.RAW_DATA_DIR
image_filenames = get_image_filenames(img_dir)
imaged_sizes = get_image_sizes(img_dir, image_filenames)
num_images = len(image_filenames)
num_joints = len(joint_names)

# Create a JSON file of Images Joints for all the data:
labels = defaultdict(list)
for i in range(num_images):
        img_name = image_filenames[i]
        for j in range(num_joints):
                joint_data = joint_annotations[j,:, i].tolist()
                img_w = imaged_sizes[i][0]
                img_h = imaged_sizes[i][1]
                normalized_joint_data = [joint_data[0]/img_w, joint_data[1]/img_h, joint_data[2]]
                labels[img_name].extend(normalized_joint_data)


# create label.json
with open(settings.CONF_DIR.joinpath("labels.json"), 'w') as f:
        json.dump(labels, f, indent=4)

# %% [markdown]
# ##### CONFIG YOLOv8:
#
# 1. **Config Yolo Data by this structure:**
#
#     ```plaintext
#     data_path/
#     ├── images/
#     │   ├── train/      # Directory containing training images
#     │   ├── val/        # Directory containing validation images
#     │   └── test/       # Directory containing test images [Optional]
#     ├── labels/
#     │   ├── train/      # Directory containing training labels (RoboFlow annotations)
#     │   └── val/        # Directory containing validation labels (RoboFlow annotations)
#     └── yaml file(s)    # YAML file(s) specifying paths to images and labels:
#         names:
#         0: person
#         path: /Users/rashajaber/Human-Pose-Estimation---AI-Development-Course/hr-lspet/data_path
#         test: images/train
#         train: images/val
#         val: images/test
#         # Keypoints
#         kpt_shape: [14, 3]   # number of keypoints, number of dims (2 for x,y or 3 for x,y,visible)
#         flip_idx: []
#     ```
#
# 2. **Create .TxT file for joined Data annotations:**
#
#    BBOX annotation from Roboflow + Keypoints Joints given from LSP dataset all in one .TXT File, save in labels file after splitting data to train/val.
#
# 3. **Download `yolov8n.yaml` from:**
#
#    [ultralytics/ultralytics GitHub repository](https://github.com/ultralytics/ultralytics/tree/main/ultralytics/cfg/models/v8)

# %%
# Directories and files paths:
raw_data_dir =  settings.RAW_DATA_DIR
gt_dir = settings.YOLO_OUTPUT_DATA_DIR.joinpath('yolo_gt_labels')
project_dir = settings.YOLO_OUTPUT_DATA_DIR

train_imgs_path = project_dir.joinpath('data/images/train')
train_label_path = project_dir.joinpath('data/labels/train')
test_imgs_path = project_dir.joinpath('data/images/val')
test_label_path = project_dir.joinpath('data/labels/val')
predicted_labels = project_dir.joinpath('results/raw_labels')

# %%
# Config Yolo Data: Split data to train, val and test, create folders and manage labels
cli.create_yolo_data(gt_dir, project_dir, raw_data_dir, settings.LABELS_CONFIG_PATH)
# Out:
# 2024-07-13 16:12:18,258 - WARNING - No bbox data detectec for file im01084.png
# 2024-07-13 16:12:19,593 - WARNING - No bbox data detectec for file im04459.png
# 2024-07-13 16:12:21,522 - WARNING - No bbox data detectec for file im00031.png
# 2024-07-13 16:12:21,678 - WARNING - No bbox data detectec for file im02132.png

# %% [markdown]
# #### Clean Data

# %%
# clean train, val data from non annotated images;

def clean_data(images_dir: str,labels_dir: str) -> None:
    label_names = [name for name in os.listdir(labels_dir) if name.endswith('.txt')]
    for label_file in label_names:
        label_path = os.path.join(labels_dir, label_file)

        with open(label_path, 'r') as file:
            lines = file.readlines()
        img_base_name = os.path.splitext(label_file)[0]
    
        if len(lines) == 0:
            os.remove(label_path)
            # Remove corresponding image if annotation file is empty
            img_path = os.path.join(images_dir, f"{img_base_name}.jpg")
            if os.path.exists(img_path):
                os.remove(img_path)
            img_path = os.path.join(images_dir, f"{img_base_name}.png")
            if os.path.exists(img_path):
                os.remove(img_path)
            continue
        
clean_data(train_imgs_path, train_label_path)
clean_data(test_imgs_path, test_label_path)
print(f"Cleaning results for train data is {len(os.listdir(train_label_path))} and Val data {len(os.listdir(test_label_path))}" if (len(os.listdir(train_imgs_path))==len(os.listdir(train_label_path))) and  (len(os.listdir(test_imgs_path))==len(os.listdir(test_label_path))) else 0)

# %%
from train import train_yolo
dataconfig_path=settings.YOLO_OUTPUT_DATA_DIR.joinpath('congig/yolo_data.yaml')
modelconfig_path=settings.YOLO_OUTPUT_DATA_DIR.joinpath('congig/yolov8n.yaml')
model_weights= settings.DATA_DIR.joinpath('research/runs')
batch_size = settings.BATCH_SIZE
epochs = settings.EPOCHS

# train the model :
train_yolo(dataconfig_path=dataconfig_path,
           modelconfig_path=modelconfig_path,
           batch_size=batch_size,
           epochs=epochs)

# %%
import optuna

batch_size = trial.suggest_int('batch_size', 16, 64, step=16)
learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
weight_decay = trial.suggest_loguniform('weight_decay', 1e-6, 1e-3)
batch_size

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)
# Print best parameters and corresponding IoU
print("Best hyperparameters:", study.best_params)
print("Best validation IoU:", study.best_value)

# %%
from predict import predict_yolo
from src.common import vis

def is_bbox_appropriate(bbox_x, bbox_y, bbox_w, bbox_h, keypoints):
    """
    Check if the bounding box is appropriate for the given keypoints.
    """
    for i in range(0, len(keypoints), 3):
        kp_x, kp_y, v = keypoints[i], keypoints[i+1], keypoints[i+2]
        if v == 1:  # if the keypoint is visible
            if not (bbox_x <= kp_x <= bbox_x + bbox_w and bbox_y <= kp_y <= bbox_y + bbox_h):
                return False
    return True

non_predicted_images = []
model_path=settings.BASE_DIR.joinpath('research/best7.pt')
save_path=settings.YOLO_OUTPUT_DATA_DIR.joinpath('results/raw_labels')
image_keypoints =[]
list_img_paths =  [os.path.join(settings.RAW_DATA_DIR, item) for item in os.listdir(test_imgs_path)][249:]#[os.path.join(settings.RAW_DATA_DIR, item) for item in os.listdir(train_imgs_path)] +
#'im04772.png','im05907.png', 'im09683.png', 'im05085.png', 'im04364.png' os.path.join(settings.RAW_DATA_DIR, item) for item in os.listdir(settings.RAW_DATA_DIR)


# Prediction
with torch.no_grad():
    for i, img_path in enumerate(list_img_paths):
        img_name = os.path.basename(os.path.normpath(img_path))
        logger.info(f"Predicting #{i}, Image:{img_name} ")
        pred = predict_yolo(image_path=img_path, 
                    model_path=model_path, 
                    save_path=save_path)
        if isinstance(pred, str):
            non_predicted_images.append(pred)
        # if isinstance(pred, list) and not is_bbox_appropriate(**pred, image_keypoints[i]):
        #     vis.visualize_bboxes(settings.RAW_DATA_DIR.joinpath(f'{img_name }'),
        #              settings.YOLO_OUTPUT_DATA_DIR.joinpath(f"{img_name.split('.')[0]}.json"))
            
if non_predicted_images:
    pd.DataFrame(non_predicted_images, columns=['file_name']).to_csv('non_predicted_images.csv', index=False)

# %% [markdown]
# #### IoU Calculation

# %%
from src.results import eval
train_labels = os.listdir(train_label_path)
val_labels = os.listdir(test_label_path)
all_labels = os.listdir(predicted_labels)


# Process training labels
train_gt = np.empty((0, 4))
train_preds = np.empty((0, 4))
for train_label in train_labels:
    with open(os.path.join(train_label_path, train_label), 'r') as file:
        first_line = file.readline().strip()
        bbox_label = np.array([float(value) for value in first_line.split()[-4:]])
    json_file = f"{train_label.split('.')[0]}.json"
    json_path = os.path.join(predicted_labels, json_file)
    if os.path.exists(json_path):
        with open(os.path.join(predicted_labels, json_file), 'r') as file:
            data = json.load(file)
        bbox_pred = np.array(data['bbox'])
        train_preds = np.vstack((train_preds, bbox_pred))
        train_gt = np.vstack((train_gt, bbox_label))
    # else:
    #     print(f"Labelled File {json_file} NOT FOUND")
        
train_mean_iou = eval.evaluate_model(train_gt, train_preds)
print(f"Train Mean IoU over {len(train_preds)} is: {train_mean_iou}")

# Process validation labels
val_gt = np.empty((0, 4))
val_preds = np.empty((0, 4))

for val_label in val_labels:
    with open(os.path.join(test_label_path, val_label), 'r') as file:
        first_line = file.readline().strip()
        bbox_label = np.array([float(value) for value in first_line.split()[-4:]])
    json_file = f"{val_label.split('.')[0]}.json"
    json_path = os.path.join(predicted_labels, json_file)
    if os.path.exists(json_path):
        with open(json_path, 'r') as file:
            data = json.load(file)
        bbox_pred = np.array(data['bbox'])
        val_preds = np.vstack((val_preds, bbox_pred))
        val_gt = np.vstack((val_gt, bbox_label))
    # else:
    #     print(f"Labelled File {json_file} NOT FOUND")
        
    
val_mean_iou = eval.evaluate_model(val_gt, val_preds)
print(f"Vlidation Mean IoU over {len(val_preds)} is: {val_mean_iou}")
